# %%
import numpy as np

# %%
N = 


for k in range(N):
    x = x_old
    x_temp = x
    while np.abs(x - x_temp) > 0.1:
        f = lambda x : x
        f_prime = lambda x : np.ones(len(x))
        epsilon_x = np.linalg.inv(sigma_x) * (x - A @ f(x_old) - B @ u)
        epsilon_y = np.linalg.inv(sigma_y) * (y - C @ f(x))
        x = x + tau * (-epsilon_x + f_prime(x) * C.T * epsilon_y)
